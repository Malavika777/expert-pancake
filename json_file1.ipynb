# %%
book={}
book["tom"]={
    "name":"tom",
    "address":"66a4 anna nagar",
    "phone":"247238689"
}
book["bob"]={
    "name":"bob",
    "address":"66 a4 ammam street",
    "phone":"87754355"
}
import json
s=json.dumps(book)
with open("C:\\Users\\srini\\OneDrive\\data\\book.txt","w") as f:
    f.write(s)
